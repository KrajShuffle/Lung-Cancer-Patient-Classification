# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import balanced_accuracy_score
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn import svm
from mpl_toolkits import mplot3d

# %%
cancer = pd.read_excel('cancer patient data sets.xlsx')
cancer = cancer.drop(columns = 'Patient Id')
cancer
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# 2                       5             5                     4              6
# 3                       7             6                     7              7
# 4                       7             7                     6              7
# ..                    ...           ...                   ...            ...
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0          4  ...        3            4                    2         2
# 1          2  ...        1            3                    7         8
# 2          7  ...        8            7                    9         2
# 3          7  ...        4            2                    3         1
# 4          7  ...        3            2                    4         1
# ..       ...  ...      ...          ...                  ...       ...
# 995        7  ...        5            3                    2         7
# 996        7  ...        9            6                    5         7
# 997        7  ...        8            7                    9         2
# 998        7  ...        3            2                    4         1
# 999        7  ...        8            7                    9         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0                        3                         1              2
# 1                        6                         2              1
# 2                        1                         4              6
# 3                        4                         5              6
# 4                        4                         2              4
# ..                     ...                       ...            ...
# 995                      8                         2              4
# 996                      2                         4              3
# 997                      1                         4              6
# 998                      4                         2              4
# 999                      1                         4              6
#
#      Dry Cough  Snoring   Level
# 0            3        4     Low
# 1            7        2  Medium
# 2            7        2    High
# 3            7        5    High
# 4            2        3    High
# ..         ...      ...     ...
# 995          5        3    High
# 996          1        4    High
# 997          7        2    High
# 998          2        3    High
# 999          7        2    High
#
# [1000 rows x 24 columns]

# %% [markdown]
# ## Quality Assurance Checks

# %%
# Number of Missing Values
cancer_cp = cancer.copy()
cancer.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
# Conversion of the columns to zero to 1 scale
zero_2 = {'Low' : 0, 'Medium': 0.5, 'High' : 1}
cancer_cp['Level'].replace(zero_2,inplace = True)
cancer_cp['Gender'].replace({1: 0, 2: 1}, inplace = True)
cancer_cp
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       0              2            4             5
# 1     17       0              3            1             5
# 2     35       0              4            5             6
# 3     37       0              7            7             7
# 4     46       0              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       0              6            7             7
# 996   37       1              6            8             7
# 997   25       1              4            5             6
# 998   18       1              6            8             7
# 999   47       0              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# 2                       5             5                     4              6
# 3                       7             6                     7              7
# 4                       7             7                     6              7
# ..                    ...           ...                   ...            ...
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0          4  ...        3            4                    2         2
# 1          2  ...        1            3                    7         8
# 2          7  ...        8            7                    9         2
# 3          7  ...        4            2                    3         1
# 4          7  ...        3            2                    4         1
# ..       ...  ...      ...          ...                  ...       ...
# 995        7  ...        5            3                    2         7
# 996        7  ...        9            6                    5         7
# 997        7  ...        8            7                    9         2
# 998        7  ...        3            2                    4         1
# 999        7  ...        8            7                    9         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0                        3                         1              2
# 1                        6                         2              1
# 2                        1                         4              6
# 3                        4                         5              6
# 4                        4                         2              4
# ..                     ...                       ...            ...
# 995                      8                         2              4
# 996                      2                         4              3
# 997                      1                         4              6
# 998                      4                         2              4
# 999                      1                         4              6
#
#      Dry Cough  Snoring  Level
# 0            3        4    0.0
# 1            7        2    0.5
# 2            7        2    1.0
# 3            7        5    1.0
# 4            2        3    1.0
# ..         ...      ...    ...
# 995          5        3    1.0
# 996          1        4    1.0
# 997          7        2    1.0
# 998          2        3    1.0
# 999          7        2    1.0
#
# [1000 rows x 24 columns]

# %%
cancer_cp.dtypes # All ints so we good except for level
# Out:
# Age                           int64
# Gender                        int64
# Air Pollution                 int64
# Alcohol use                   int64
# Dust Allergy                  int64
# OccuPational Hazards          int64
# Genetic Risk                  int64
# chronic Lung Disease          int64
# Balanced Diet                 int64
# Obesity                       int64
# Smoking                       int64
# Passive Smoker                int64
# Chest Pain                    int64
# Coughing of Blood             int64
# Fatigue                       int64
# Weight Loss                   int64
# Shortness of Breath           int64
# Wheezing                      int64
# Swallowing Difficulty         int64
# Clubbing of Finger Nails      int64
# Frequent Cold                 int64
# Dry Cough                     int64
# Snoring                       int64
# Level                       float64
# dtype: object

# %% [markdown]
# # Using PCA for Dimensionality Reduction Prior to Classification

# %%
# Scaling along each column so its a min of 0 and max of 1
mm_scaler = preprocessing.StandardScaler()
X_train_minmax = mm_scaler.fit_transform(cancer_cp)
X_train_minmax
cancer_cp_columns = cancer_cp.columns.values
cancer_cp_columns
cancer_norm = pd.DataFrame(X_train_minmax, columns = cancer_cp_columns)
cancer_norm
# Out:
#           Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   -0.347848 -0.819903      -0.906679    -0.214954     -0.083340
# 1   -1.681238 -0.819903      -0.413919    -1.360357     -0.083340
# 2   -0.181174 -0.819903       0.078842     0.166847      0.421751
# 3   -0.014501 -0.819903       1.557123     0.930449      0.926842
# 4    0.735531 -0.819903       1.064362     1.312250      0.926842
# ..        ...       ...            ...          ...           ...
# 995  0.568858 -0.819903       1.064362     0.930449      0.926842
# 996 -0.014501  1.219657       1.064362     1.312250      0.926842
# 997 -1.014543  1.219657       0.078842     0.166847      0.421751
# 998 -1.597901  1.219657       1.064362     1.312250      0.926842
# 999  0.818868 -0.819903       1.064362     0.166847      0.421751
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0               -0.398718     -0.743202             -1.288162      -1.167040
# 1               -0.873383     -0.272821             -1.288162      -1.167040
# 2                0.075946      0.197560             -0.205673       0.706970
# 3                1.025275      0.667941              1.418061       1.175473
# 4                1.025275      1.138323              0.876816       1.175473
# ..                    ...           ...                   ...            ...
# 995              1.025275      1.138323              0.876816       1.175473
# 996              1.025275      1.138323              0.876816       1.175473
# 997              0.075946      0.197560             -0.205673       0.706970
# 998              1.025275      1.138323              0.876816       1.175473
# 999              0.075946      0.197560             -0.205673       0.706970
#
#       Obesity  ...   Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0   -0.218941  ... -0.381548     0.065746            -0.980760 -0.870694
# 1   -1.160623  ... -1.273014    -0.387677             1.208436  2.069186
# 2    1.193582  ...  1.847119     1.426018             2.084114 -0.870694
# 3    1.193582  ...  0.064186    -0.841101            -0.542921 -1.360675
# 4    1.193582  ... -0.381548    -0.841101            -0.105081 -1.360675
# ..        ...  ...       ...          ...                  ...       ...
# 995  1.193582  ...  0.509919    -0.387677            -0.980760  1.579206
# 996  1.193582  ...  2.292852     0.972594             0.332758  1.579206
# 997  1.193582  ...  1.847119     1.426018             2.084114 -0.870694
# 998  1.193582  ... -0.381548    -0.841101            -0.105081 -1.360675
# 999  1.193582  ...  1.847119     1.426018             2.084114 -0.870694
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0                -0.328743                 -1.224625      -0.838618
# 1                 0.993281                 -0.805663      -1.384593
# 2                -1.210093                  0.032260       1.345283
# 3                 0.111931                  0.451222       1.345283
# 4                 0.111931                 -0.805663       0.253332
# ..                     ...                       ...            ...
# 995               1.874630                 -0.805663       0.253332
# 996              -0.769418                  0.032260      -0.292643
# 997              -1.210093                  0.032260       1.345283
# 998               0.111931                 -0.805663       0.253332
# 999              -1.210093                  0.032260       1.345283
#
#      Dry Cough   Snoring     Level
# 0    -0.418550  0.728655 -1.303135
# 1     1.544171 -0.628245 -0.076078
# 2     1.544171 -0.628245  1.150980
# 3     1.544171  1.407105  1.150980
# 4    -0.909231  0.050205  1.150980
# ..         ...       ...       ...
# 995   0.562810  0.050205  1.150980
# 996  -1.399911  0.728655  1.150980
# 997   1.544171 -0.628245  1.150980
# 998  -0.909231  0.050205  1.150980
# 999   1.544171 -0.628245  1.150980
#
# [1000 rows x 24 columns]

# %%
# No NaNs after normalization of dataset 
cancer_norm.isna().sum().sum()
# Out:
# 0

# %%
cancer_norm.columns
# Out:
# Index(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
# Seeing which features are correlated with Lung Cancer Level
correlation_mat = cancer_norm.corr()
level_vs_world = correlation_mat.loc['Level']
level_vs_world.sort_values(ascending = False)
# Out:
# Level                       1.000000
# Obesity                     0.827435
# Coughing of Blood           0.782092
# Alcohol use                 0.718710
# Dust Allergy                0.713839
# Balanced Diet               0.706273
# Passive Smoker              0.703594
# Genetic Risk                0.701303
# OccuPational Hazards        0.673255
# Chest Pain                  0.645461
# Air Pollution               0.636038
# Fatigue                     0.625114
# chronic Lung Disease        0.609971
# Smoking                     0.519530
# Shortness of Breath         0.497024
# Frequent Cold               0.444017
# Dry Cough                   0.373968
# Weight Loss                 0.352738
# Snoring                     0.289366
# Clubbing of Finger Nails    0.280063
# Swallowing Difficulty       0.249142
# Wheezing                    0.242794
# Age                         0.060048
# Gender                     -0.164985
# Name: Level, dtype: float64

# %%
plt.figure(figsize = (10,6))
sns.heatmap(correlation_mat);

# %% [markdown]
# ## PCA Steps

# %%
pca = PCA(n_components = 8)

# %%
cancer_norm_wo_target = cancer_norm.loc[:, cancer_norm.columns != 'Level']
cancer_norm_wo_target
# Out:
#           Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   -0.347848 -0.819903      -0.906679    -0.214954     -0.083340
# 1   -1.681238 -0.819903      -0.413919    -1.360357     -0.083340
# 2   -0.181174 -0.819903       0.078842     0.166847      0.421751
# 3   -0.014501 -0.819903       1.557123     0.930449      0.926842
# 4    0.735531 -0.819903       1.064362     1.312250      0.926842
# ..        ...       ...            ...          ...           ...
# 995  0.568858 -0.819903       1.064362     0.930449      0.926842
# 996 -0.014501  1.219657       1.064362     1.312250      0.926842
# 997 -1.014543  1.219657       0.078842     0.166847      0.421751
# 998 -1.597901  1.219657       1.064362     1.312250      0.926842
# 999  0.818868 -0.819903       1.064362     0.166847      0.421751
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0               -0.398718     -0.743202             -1.288162      -1.167040
# 1               -0.873383     -0.272821             -1.288162      -1.167040
# 2                0.075946      0.197560             -0.205673       0.706970
# 3                1.025275      0.667941              1.418061       1.175473
# 4                1.025275      1.138323              0.876816       1.175473
# ..                    ...           ...                   ...            ...
# 995              1.025275      1.138323              0.876816       1.175473
# 996              1.025275      1.138323              0.876816       1.175473
# 997              0.075946      0.197560             -0.205673       0.706970
# 998              1.025275      1.138323              0.876816       1.175473
# 999              0.075946      0.197560             -0.205673       0.706970
#
#       Obesity  ...  Coughing of Blood   Fatigue  Weight Loss  \
# 0   -0.218941  ...          -0.353971 -0.381548     0.065746
# 1   -1.160623  ...          -0.766045 -1.273014    -0.387677
# 2    1.193582  ...           1.294323  1.847119     1.426018
# 3    1.193582  ...           1.294323  0.064186    -0.841101
# 4    1.193582  ...           1.706397 -0.381548    -0.841101
# ..        ...  ...                ...       ...          ...
# 995  1.193582  ...           0.882250  0.509919    -0.387677
# 996  1.193582  ...           0.882250  2.292852     0.972594
# 997  1.193582  ...           1.294323  1.847119     1.426018
# 998  1.193582  ...           1.706397 -0.381548    -0.841101
# 999  1.193582  ...           1.294323  1.847119     1.426018
#
#      Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              -0.980760 -0.870694              -0.328743
# 1               1.208436  2.069186               0.993281
# 2               2.084114 -0.870694              -1.210093
# 3              -0.542921 -1.360675               0.111931
# 4              -0.105081 -1.360675               0.111931
# ..                   ...       ...                    ...
# 995            -0.980760  1.579206               1.874630
# 996             0.332758  1.579206              -0.769418
# 997             2.084114 -0.870694              -1.210093
# 998            -0.105081 -1.360675               0.111931
# 999             2.084114 -0.870694              -1.210093
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough   Snoring
# 0                   -1.224625      -0.838618  -0.418550  0.728655
# 1                   -0.805663      -1.384593   1.544171 -0.628245
# 2                    0.032260       1.345283   1.544171 -0.628245
# 3                    0.451222       1.345283   1.544171  1.407105
# 4                   -0.805663       0.253332  -0.909231  0.050205
# ..                        ...            ...        ...       ...
# 995                 -0.805663       0.253332   0.562810  0.050205
# 996                  0.032260      -0.292643  -1.399911  0.728655
# 997                  0.032260       1.345283   1.544171 -0.628245
# 998                 -0.805663       0.253332  -0.909231  0.050205
# 999                  0.032260       1.345283   1.544171 -0.628245
#
# [1000 rows x 23 columns]

# %%
cancer_norm_wo_target.var(axis = 0)
# Out:
# Age                         1.001001
# Gender                      1.001001
# Air Pollution               1.001001
# Alcohol use                 1.001001
# Dust Allergy                1.001001
# OccuPational Hazards        1.001001
# Genetic Risk                1.001001
# chronic Lung Disease        1.001001
# Balanced Diet               1.001001
# Obesity                     1.001001
# Smoking                     1.001001
# Passive Smoker              1.001001
# Chest Pain                  1.001001
# Coughing of Blood           1.001001
# Fatigue                     1.001001
# Weight Loss                 1.001001
# Shortness of Breath         1.001001
# Wheezing                    1.001001
# Swallowing Difficulty       1.001001
# Clubbing of Finger Nails    1.001001
# Frequent Cold               1.001001
# Dry Cough                   1.001001
# Snoring                     1.001001
# dtype: float64

# %%
cancer_norm_wo_target.cov()
# Out:
#                                Age    Gender  Air Pollution  Alcohol use  \
# Age                       1.001001 -0.202288       0.099594     0.151894
# Gender                   -0.202288  1.001001      -0.247159    -0.227864
# Air Pollution             0.099594 -0.247159       1.001001     0.748041
# Alcohol use               0.151894 -0.227864       0.748041     1.001001
# Dust Allergy              0.035237 -0.204517       0.638142     0.819463
# OccuPational Hazards      0.062240 -0.192536       0.609534     0.879666
# Genetic Risk              0.073224 -0.222950       0.705982     0.878088
# chronic Lung Disease      0.129081 -0.205266       0.627328     0.764340
# Balanced Diet             0.004868 -0.099841       0.525398     0.654006
# Obesity                   0.034372 -0.123937       0.602070     0.669982
# Smoking                   0.075408 -0.207131       0.482384     0.547582
# Passive Smoker            0.004913 -0.185011       0.607371     0.593170
# Chest Pain                0.012876 -0.218644       0.586320     0.717960
# Coughing of Blood         0.053059 -0.146652       0.608437     0.668280
# Fatigue                   0.095154 -0.116583       0.211936     0.237483
# Weight Loss               0.107053 -0.058051       0.258274     0.208059
# Shortness of Breath       0.035365 -0.046018       0.269828     0.436222
# Wheezing                 -0.095450 -0.076380       0.055423     0.180998
# Swallowing Difficulty    -0.105939 -0.058382      -0.080999    -0.114187
# Clubbing of Finger Nails  0.039298 -0.034253       0.241306     0.415408
# Frequent Cold            -0.012719 -0.000526       0.174714     0.180959
# Dry Cough                 0.012140 -0.123124       0.261750     0.211489
# Snoring                  -0.004705 -0.181800      -0.021364     0.122817
#
#                           Dust Allergy  OccuPational Hazards  Genetic Risk  \
# Age                           0.035237              0.062240      0.073224
# Gender                       -0.204517             -0.192536     -0.222950
# Air Pollution                 0.638142              0.609534      0.705982
# Alcohol use                   0.819463              0.879666      0.878088
# Dust Allergy                  1.001001              0.836696      0.788693
# OccuPational Hazards          0.836696              1.001001      0.893942
# Genetic Risk                  0.788693              0.893942      1.001001
# chronic Lung Disease          0.620176              0.859143      0.837068
# Balanced Diet                 0.647845              0.692201      0.680585
# Obesity                       0.701377              0.722914      0.730557
# Smoking                       0.359050              0.498191      0.543803
# Passive Smoker                0.560563              0.555867      0.609681
# Chest Pain                    0.640624              0.776395      0.832583
# Coughing of Blood             0.625917              0.646593      0.632869
# Fatigue                       0.332804              0.268112      0.230761
# Weight Loss                   0.322078              0.176402      0.272015
# Shortness of Breath           0.519201              0.366848      0.458659
# Wheezing                      0.305155              0.179105      0.205178
# Swallowing Difficulty         0.031172             -0.002856     -0.063011
# Clubbing of Finger Nails      0.346060              0.366814      0.358173
# Frequent Cold                 0.219609              0.077243      0.087179
# Dry Cough                     0.300496              0.160047      0.194594
# Snoring                       0.052897              0.022939     -0.056888
#
#                           chronic Lung Disease  Balanced Diet   Obesity  ...  \
# Age                                   0.129081       0.004868  0.034372  ...
# Gender                               -0.205266      -0.099841 -0.123937  ...
# Air Pollution                         0.627328       0.525398  0.602070  ...
# Alcohol use                           0.764340       0.654006  0.669982  ...
# Dust Allergy                          0.620176       0.647845  0.701377  ...
# OccuPational Hazards                  0.859143       0.692201  0.722914  ...
# Genetic Risk                          0.837068       0.680585  0.730557  ...
# chronic Lung Disease                  1.001001       0.623255  0.602357  ...
# Balanced Diet                         0.623255       1.001001  0.707630  ...
# Obesity                               0.602357       0.707630  1.001001  ...
# Smoking                               0.579164       0.646036  0.487282  ...
# Passive Smoker                        0.573272       0.725849  0.682571  ...
# Chest Pain                            0.783430       0.799006  0.673824  ...
# Coughing of Blood                     0.603590       0.745800  0.815620  ...
# Fatigue                               0.247945       0.401079  0.553342  ...
# Weight Loss                           0.104184      -0.006550  0.313809  ...
# Shortness of Breath                   0.182608       0.343967  0.406610  ...
# Wheezing                              0.057271       0.063994  0.094381  ...
# Swallowing Difficulty                 0.007287       0.046854  0.127340  ...
# Clubbing of Finger Nails              0.298321       0.042009  0.149243  ...
# Frequent Cold                         0.028787       0.264195  0.288657  ...
# Dry Cough                             0.114276       0.332327  0.200819  ...
# Snoring                               0.043418       0.152830  0.039462  ...
#
#                           Coughing of Blood   Fatigue  Weight Loss  \
# Age                                0.053059  0.095154     0.107053
# Gender                            -0.146652 -0.116583    -0.058051
# Air Pollution                      0.608437  0.211936     0.258274
# Alcohol use                        0.668280  0.237483     0.208059
# Dust Allergy                       0.625917  0.332804     0.322078
# OccuPational Hazards               0.646593  0.268112     0.176402
# Genetic Risk                       0.632869  0.230761     0.272015
# chronic Lung Disease               0.603590  0.247945     0.104184
# Balanced Diet                      0.745800  0.401079    -0.006550
# Obesity                            0.815620  0.553342     0.313809
# Smoking                            0.555845  0.200230    -0.213150
# Passive Smoker                     0.636860  0.378297     0.058394
# Chest Pain                         0.712871  0.251386    -0.001093
# Coughing of Blood                  1.001001  0.482022     0.105963
# Fatigue                            0.482022  1.001001     0.469987
# Weight Loss                        0.105963  0.469987     1.001001
# Shortness of Breath                0.319096  0.399024     0.575072
# Wheezing                          -0.085784  0.174652     0.331510
# Swallowing Difficulty              0.086376  0.149711     0.053437
# Clubbing of Finger Nails          -0.066509  0.040735     0.376860
# Frequent Cold                      0.244480  0.408323     0.160509
# Dry Cough                          0.147806  0.271438     0.188787
# Snoring                            0.088032  0.231980    -0.189296
#
#                           Shortness of Breath  Wheezing  \
# Age                                  0.035365 -0.095450
# Gender                              -0.046018 -0.076380
# Air Pollution                        0.269828  0.055423
# Alcohol use                          0.436222  0.180998
# Dust Allergy                         0.519201  0.305155
# OccuPational Hazards                 0.366848  0.179105
# Genetic Risk                         0.458659  0.205178
# chronic Lung Disease                 0.182608  0.057271
# Balanced Diet                        0.343967  0.063994
# Obesity                              0.406610  0.094381
# Smoking                             -0.023282 -0.047107
# Passive Smoker                       0.063011  0.200484
# Chest Pain                           0.237282  0.107318
# Coughing of Blood                    0.319096 -0.085784
# Fatigue                              0.399024  0.174652
# Weight Loss                          0.575072  0.331510
# Shortness of Breath                  1.001001  0.207772
# Wheezing                             0.207772  1.001001
# Swallowing Difficulty               -0.200678  0.393881
# Clubbing of Finger Nails             0.474749  0.338610
# Frequent Cold                        0.351840  0.098954
# Dry Cough                            0.493824  0.054443
# Snoring                             -0.159451  0.116299
#
#                           Swallowing Difficulty  Clubbing of Finger Nails  \
# Age                                   -0.105939                  0.039298
# Gender                                -0.058382                 -0.034253
# Air Pollution                         -0.080999                  0.241306
# Alcohol use                           -0.114187                  0.415408
# Dust Allergy                           0.031172                  0.346060
# OccuPational Hazards                  -0.002856                  0.366814
# Genetic Risk                          -0.063011                  0.358173
# chronic Lung Disease                   0.007287                  0.298321
# Balanced Diet                          0.046854                  0.042009
# Obesity                                0.127340                  0.149243
# Smoking                                0.236378                 -0.041188
# Passive Smoker                         0.349272                 -0.035572
# Chest Pain                             0.071856                  0.081468
# Coughing of Blood                      0.086376                 -0.066509
# Fatigue                                0.149711                  0.040735
# Weight Loss                            0.053437                  0.376860
# Shortness of Breath                   -0.200678                  0.474749
# Wheezing                               0.393881                  0.338610
# Swallowing Difficulty                  1.001001                 -0.119860
# Clubbing of Finger Nails              -0.119860                  1.001001
# Frequent Cold                          0.132496                  0.242772
# Dry Cough                             -0.055484                  0.307578
# Snoring                                0.210751                 -0.017555
#
#                           Frequent Cold  Dry Cough   Snoring
# Age                           -0.012719   0.012140 -0.004705
# Gender                        -0.000526  -0.123124 -0.181800
# Air Pollution                  0.174714   0.261750 -0.021364
# Alcohol use                    0.180959   0.211489  0.122817
# Dust Allergy                   0.219609   0.300496  0.052897
# OccuPational Hazards           0.077243   0.160047  0.022939
# Genetic Risk                   0.087179   0.194594 -0.056888
# chronic Lung Disease           0.028787   0.114276  0.043418
# Balanced Diet                  0.264195   0.332327  0.152830
# Obesity                        0.288657   0.200819  0.039462
# Smoking                        0.039625   0.010111  0.189244
# Passive Smoker                 0.104658   0.120882  0.248192
# Chest Pain                     0.042980   0.142322  0.140176
# Coughing of Blood              0.244480   0.147806  0.088032
# Fatigue                        0.408323   0.271438  0.231980
# Weight Loss                    0.160509   0.188787 -0.189296
# Shortness of Breath            0.351840   0.493824 -0.159451
# Wheezing                       0.098954   0.054443  0.116299
# Swallowing Difficulty          0.132496  -0.055484  0.210751
# Clubbing of Finger Nails       0.242772   0.307578 -0.017555
# Frequent Cold                  1.001001   0.516435  0.336180
# Dry Cough                      0.516435   1.001001  0.176322
# Snoring                        0.336180   0.176322  1.001001
#
# [23 rows x 23 columns]

# %%
X_pca = pca.fit_transform(cancer_norm_wo_target)

# %%
# Cancer_target_column as int
cancer_level_int = cancer_cp['Level'].replace({0.5 : 1, 1:2})
cancer_level_int = cancer_level_int.astype(int)
cancer_level_int
# Out:
# 0      0
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 995    2
# 996    2
# 997    2
# 998    2
# 999    2
# Name: Level, Length: 1000, dtype: int64

# %%
cancer_level_nomid = cancer_level_int[cancer_level_int != 1]
cancer_level_nomid
# Out:
# 0      0
# 2      2
# 3      2
# 4      2
# 5      2
#       ..
# 995    2
# 996    2
# 997    2
# 998    2
# 999    2
# Name: Level, Length: 668, dtype: int64

# %%
pca_res_df = pd.DataFrame(np.insert(X_pca, 8, cancer_level_int, axis=1), columns=['feat_1', 'feat_2','feat_3', 'feat_4', 'feat_5', 'feat_6', 'feat_7', 'feat_8','level'])
pca_res_df
# Out:
#        feat_1    feat_2    feat_3    feat_4    feat_5    feat_6    feat_7  \
# 0   -2.532266 -0.685607 -0.056138  0.308614  0.220354 -0.737878  0.945302
# 1   -2.499235  1.046103 -0.491506 -1.867262  0.048598  0.965305  2.804170
# 2    1.710896  2.877557 -0.429408  2.537108 -1.172250 -0.785251  1.236994
# 3    3.931440 -1.240072 -0.945878  1.762587  1.569949  0.688491  0.140736
# 4    3.599374 -2.584447  0.532676  0.990435  0.034351 -0.647047 -0.026446
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  3.713500 -1.619119 -1.489596 -1.439822  0.233083 -0.563616  0.171929
# 996  4.032301 -0.276396 -0.348624 -1.001963 -1.508344 -0.324727 -1.386588
# 997  1.512550  2.928771 -0.433275  2.529483 -2.331951  0.658143  0.320224
# 998  3.355887 -2.564568  0.370874  0.768549 -1.527850  1.766069 -0.140660
# 999  1.990658  2.893785 -0.205584  2.728470 -0.844389 -1.490299  0.831263
#
#        feat_8  level
# 0    1.119684    0.0
# 1   -1.099592    1.0
# 2    0.491316    2.0
# 3   -0.490057    2.0
# 4   -0.223939    2.0
# ..        ...    ...
# 995 -1.071563    2.0
# 996  1.651650    2.0
# 997  0.507382    2.0
# 998  0.131211    2.0
# 999 -0.014981    2.0
#
# [1000 rows x 9 columns]

# %%
pca_res_nomid = pca_res_df[pca_res_df.level != 1]
pca_res_nomid
# Out:
#        feat_1    feat_2    feat_3    feat_4    feat_5    feat_6    feat_7  \
# 0   -2.532266 -0.685607 -0.056138  0.308614  0.220354 -0.737878  0.945302
# 2    1.710896  2.877557 -0.429408  2.537108 -1.172250 -0.785251  1.236994
# 3    3.931440 -1.240072 -0.945878  1.762587  1.569949  0.688491  0.140736
# 4    3.599374 -2.584447  0.532676  0.990435  0.034351 -0.647047 -0.026446
# 5    1.710896  2.877557 -0.429408  2.537108 -1.172250 -0.785251  1.236994
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  3.713500 -1.619119 -1.489596 -1.439822  0.233083 -0.563616  0.171929
# 996  4.032301 -0.276396 -0.348624 -1.001963 -1.508344 -0.324727 -1.386588
# 997  1.512550  2.928771 -0.433275  2.529483 -2.331951  0.658143  0.320224
# 998  3.355887 -2.564568  0.370874  0.768549 -1.527850  1.766069 -0.140660
# 999  1.990658  2.893785 -0.205584  2.728470 -0.844389 -1.490299  0.831263
#
#        feat_8  level
# 0    1.119684    0.0
# 2    0.491316    2.0
# 3   -0.490057    2.0
# 4   -0.223939    2.0
# 5    0.491316    2.0
# ..        ...    ...
# 995 -1.071563    2.0
# 996  1.651650    2.0
# 997  0.507382    2.0
# 998  0.131211    2.0
# 999 -0.014981    2.0
#
# [668 rows x 9 columns]

# %%
pca_res_df['level'].value_counts().dtype
# Out:
# dtype('int64')

# %%
# Explained Variance 
print(pca.explained_variance_ratio_) # Pretty low explained variance ngl
# Out:
# [0.39580565 0.11740061 0.08769539 0.06596929 0.05649457 0.05286558
#  0.0343725  0.03003148]

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.8406350590371939

# %%
sns.scatterplot(data=pca_res_df, x='feat_1', y='feat_2', hue = cancer_level_int);

# %%
sns.scatterplot(data=pca_res_nomid, x='feat_1', y='feat_2', hue = cancer_level_nomid);

# %% [markdown]
# ### 3D Plots to Check if Really the third cluster exists on third plane

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
temp =pd.Categorical(pca_res_df['level'])
my_color=temp.codes

# %%
ax = plt.axes(projection = '3d')
sns.set_style('dark')
scatter_1 = ax.scatter3D(pca_res_df['feat_1'], pca_res_df['feat_2'], pca_res_df['feat_3'], c = my_color, cmap = 'Spectral', label = '0')
ax.legend()

# %% [markdown]
# ## Train-Test Split

# %%
#  splits our X and y into train and test sets, with the testing data being 25% of the size of the training set
X_train, X_test, y_train, y_test = train_test_split(pca_res_df[['feat_1', 'feat_2', 'feat_3']],cancer_level_int , test_size=0.75)

# %%
X_train
# Out:
#        feat_1    feat_2    feat_3
# 132  1.582771  2.977513 -0.187598
# 684  4.606017  1.533906 -1.392639
# 102  1.995673  2.897267 -0.188035
# 310  4.195536 -0.351980 -0.467595
# 337  3.931440 -1.240072 -0.945878
# ..        ...       ...       ...
# 144 -2.532266 -0.685607 -0.056138
# 600 -3.949178 -1.503158  1.582748
# 738 -2.675365  0.327091 -1.828930
# 936 -4.468956 -0.496191  0.768653
# 613 -3.391352 -1.556927  0.154388
#
# [250 rows x 3 columns]

# %%
pd.DataFrame(X_test)
# Out:
#        feat_1    feat_2    feat_3
# 68   3.639501 -2.556594  0.673063
# 989  3.931440 -1.240072 -0.945878
# 485 -3.141287 -1.247200 -0.419262
# 90   1.108259  2.746357  3.157289
# 28   3.774077 -0.023033 -1.040883
# ..        ...       ...       ...
# 800  3.554744  0.236573  1.098114
# 383 -4.453797 -0.447732  0.859844
# 138 -2.248463  1.844463 -1.886987
# 626  1.100735  2.741134  3.130967
# 874  3.673374 -1.646971 -1.629983
#
# [750 rows x 3 columns]

# %% [markdown]
# # KNN

# %%
classifier = KNeighborsClassifier(n_neighbors= 1) # Initialize a classifier here
## Fit and predict using X_train, y_train, and X_test
classifier.fit(X_train, y_train) # Fit classifier to your X_train and y_train
pred = classifier.predict(X_test)  # Generate predictions based on X_test

# %%
pred[:10]
# Out:
# array([2, 2, 0, 1, 2, 2, 2, 1, 1, 1])

# %% [markdown]
# ## Scoring Metric

# %%
score = sum(pred == y_test) / len(pred)
score
# Out:
# 1.0

# %%
cm = metrics.confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[232   0   0]
#  [  0 250   0]
#  [  0   0 268]]

# %%
fig = plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True);
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
fig.savefig('KNN_other Classifier Scoring Metric')

# %% [markdown]
# ### Determining Optimal K

# %%
error_rate = []
for i in list(range(1,40)):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(list(range(1,40)),error_rate,color='black', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:",min(error_rate),"at K =",(error_rate.index(min(error_rate)) + 1))
# Out:
# Minimum error: 0.0 at K = 1

# %% [markdown]
# ## Accuracy and Consistency of Model Across Various Splits

# %%
cm_list = []
scores_50 = []
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(pca_res_df[['feat_1', 'feat_2', 'feat_3']],cancer_level_int , test_size=0.75)
    
    classifier = KNeighborsClassifier(n_neighbors= 1) # Initialize a classifier here
    ## Fit and predict using X_train, y_train, and X_test
    classifier.fit(X_train, y_train) # Fit classifier to your X_train and y_train
    pred = classifier.predict(X_test)  # Generate predictions based on X_test
    
    score = sum(pred == y_test) / len(pred)
    scores_50.append(score)
    
    cm = metrics.confusion_matrix(y_test, pred)
    cm_list.append(cm)
scores_50[:10]
# Out:
# [0.9866666666666667,
#  1.0,
#  0.9866666666666667,
#  1.0,
#  1.0,
#  1.0,
#  1.0,
#  0.9733333333333334,
#  1.0,
#  0.9866666666666667]

# %%
scores_df = pd.DataFrame(scores_50, columns = ['scores'])
scores_df[:10]
# Out:
#      scores
# 0  0.986667
# 1  1.000000
# 2  0.986667
# 3  1.000000
# 4  1.000000
# 5  1.000000
# 6  1.000000
# 7  0.973333
# 8  1.000000
# 9  0.986667

# %%
def truncate(x):
    return float("{:.3f}".format(x))

# %%
scores_df['scores_tru'] = scores_df['scores'].apply(truncate)

# %%
scores_df['scores_tru'].value_counts()
# Out:
# 1.000    659
# 0.987    295
# 0.973     39
# 0.960      4
# 0.976      1
# 0.963      1
# 0.985      1
# Name: scores_tru, dtype: int64

# %%
figures = sns.countplot(data = scores_df, x = 'scores_tru')
plt.title('Accuracy Scores for 1000 Random KNN Train & Test Iterations', fontsize = 11)
plt.xlabel('Unique Accuracy Scores')
plt.ylabel('counts')
plt.savefig('Consistency Metric 1000')
